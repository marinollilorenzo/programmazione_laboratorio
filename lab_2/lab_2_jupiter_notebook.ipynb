# %% [markdown]
# # Laboratorio 2
#
# ## Comandi da terminale
# Alcuni comandi da terminale per poter verificare quanto tempo ci mette l'interprete in determianto codice

# %%
# %timeit [n*n for n in range(200)]

# %%
# %%timeit
lista = []
for n in range(200):
    lista.append(n*n)

# %%
salary_list = [100000, 200000, 150000, 120000, 80000, 750000]

[(lambda x: x*1.1)(salary) for salary in salary_list]

list(map(lambda x: x*1.1*100//100, salary_list))

# %%
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

list(filter(lambda job : "Python" in job["job_skills"] and job["remote"], jobs_data))

# %%
# %%writefile mymodule.py

colors = ["red", "blue", "green"]

# %%
from mymodule import colors

colors
# Out:
# ['red', 'blue', 'green']
