# %% [markdown]
# ES 1

# %%
lst_input = [ n for n in range(8)]

lst = [n for n in lst_input if n % 2 != 0]
print(lst)

# %% [markdown]
# Es 2

# %%
lst_inpt = [[1, 2, 3], [4, 5], [6, 7, 8, 1]]

lst = [n for l in lst_inpt for n in l]
print(lst)

# %% [markdown]
# Es 3

# %%
lst_a = [1, 3, 5, 7]
lst_b = [2, 4, 6]

lst = [x * y for x in lst_a for y in lst_b if x * y > 10]
print(lst)

# %% [markdown]
# Es 4

# %%
lst_inpt = [i for i in range(1, 21)]

lst = [(a,b,c) for a in lst_inpt for b in lst_inpt for c in lst_inpt if a ** 2 + b ** 2 == c ** 2]
print(lst)

# %% [markdown]
# Es 5

# %%
lst_a = [0, 1, 3, 4]
lst_b = ['a', 'b', 'c']

def is_pari(x:int)->bool:
    return x%2 == 0

lst = [(a,b) for a in lst_a for i,b in enumerate(lst_b) if is_pari(a) and not is_pari(i)]

print(lst)

# %% [markdown]
# Es 8

# %%
inpt = "the cat sat on the mat the cat".split(" ")
dct = {word:inpt.count(word) for word in inpt}
print(dct)
# Out:
# {'the': 3, 'cat': 2, 'sat': 1, 'on': 1, 'mat': 1}

# %% [markdown]
# Es 9
